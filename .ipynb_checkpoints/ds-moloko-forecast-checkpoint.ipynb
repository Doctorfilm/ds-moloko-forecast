# %% [markdown]
# ## Moloko Studio
#
# **Фотостудия Luce+Moloko** предоставляет в аренду залы для фотосъёмок. За два с половиной года накоплена история бронирований, отмен, предоплат и доп.услуг.
# Цель проекта — провести анализ этой статистики, чтобы выявить тренды, слабые места и зоны роста. Главная задача — **увеличить загруженность студий, выручку и качество клиентского сервиса**.
#
# ---
#
# **Бизнес-задачи**
#
# * **Анализ загрузки залов** по дням, часам и залам
#   → выявить «мёртвые часы» и залы с недозагрузкой.
#
# * **Прогноз выручки и бронирований**
#   → помогает в планировании бюджета, ресурсов, акций.
#
# * **Кластеризация клиентов**
#   → сегментация на новчиков, постоянных, командных и т.д.
#
# * **Анализ доп.услуг**
#   → определить наиболее маржинальные и востребованные услуги.
#
# * **Определение «провальных» недель**
#   → позволяет запускать точечные акции и промо-загрузки.
#
# ---
#
# **Структура проекта: *Moloko Studio Insights***
#
# 1. **Загрузка и обработка данных**
#
# * Преименование и очистка столбцов;
# * Объединение таблиц;
# * Базовый визуальный анализ (распределения, пропуски, перекосы).
#
# 2. **Исследовательский анализ данных**
#
# * Генерация дополнительных признаков (цена за час, неделя года и т.д.);
# * Корреляционный анализ (в том числе `Phik`);
# * Анализ клиентов, залов, дополнительных услуг;
# * Поиск перекосов, трендов и точек роста.
#
# 3. **Прогнозирование**
#
# * Прогноз выручки по месяцам;
# * Прогноз бронирования на 2025 год (по неделям и залам);
# * Поиск «провальных» недель — тех, где ожидается минимальная загрузка.
#
# 4. **Финальный вывод**
#
# * Обобщение наблюдений;
# * Выводы о стратегии: почему выручка растёт, несмотря на падение активности;
# * Рекомендации по управлению студиями, маркетингу и ценообразованию.

# %%
# -------------------------------------------------------
# 1. Импорт базовых библиотек для анализа и визуализации
# -------------------------------------------------------
import re                                   # Работа с регулярными выражениями
import pandas as pd                         # Таблицы и датафреймы
import numpy as np                          # Векторные и матричные операции
import seaborn as sns                       # Визуализация
import matplotlib.pyplot as plt             # Графики
from datetime import datetime, timedelta    # Работа с датами
import calendar

# -------------------------------------------------------
# 2. Phi-корреляция и отчёты
# -------------------------------------------------------
import phik 
from phik import phik_matrix
from phik.report import plot_correlation_matrix

# -------------------------------------------------------
# 3. Масштабирование и кластеризация
# -------------------------------------------------------
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from prophet import Prophet

# -------------------------------------------------------
# 4. Пользовательские функции визуализации (group_graph.py)
# -------------------------------------------------------
from group_graph import hist_graph, bar_graph, kde_graph_count, kde_graph

# -------------------------------------------------------
# 5. Общие настройки среды
# -------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")                     # Отключение предупреждений

pd.set_option('display.max_columns', None)            # Отображать все колонки
pd.options.display.float_format = '{:,.2f}'.format    # Формат чисел с запятой
sns.set_style("darkgrid")                             # Темная сетка для графиков

# -------------------------------------------------------
# 6. Константы проекта
# -------------------------------------------------------
RANDOM_STATE = 210425   # Фиксированное случайное состояние для воспроизводимости
TEST_SIZE = 0.25        # Размер тестовой выборки (25%)

# %% [markdown]
# ## Загрузка и обработка данных
#
# На этом этапе производим импорт двух CSV-файлов, содержащих историю бронирований:
# Moloko_1.0.csv — данные из первой версии системы бронирований студии Moloko;
# Luce+Moloko_2.0.csv — данные из более новой системы, объединяющей две площадки: Luce и Moloko.
# Файлы разделены точкой с запятой, что характерно для выгрузок из Excel/CRM.

# %%
# 1. Загрузка  датасета
df_moloko = pd.read_csv('dataset/Moloko_1.0.csv', sep=';')
# 2. Загрузка  датасета
df_luce = pd.read_csv('dataset/Luce+Moloko_2.0.csv', sep=';')

# %% [markdown]
# ### Приведение названий столбцов к единому формату
# В исходных таблицах названия колонок были заданы на русском языке, местами с разной пунктуацией или регистрацией.
# Для удобства анализа и дальнейшего программирования приводим имена колонок к единому, читаемому и англоязычному формату — в snake_case.

# %%
# 1. Список названий всех колонок (по согласованному шаблону)
col_name = [
    'id', 'location', 'hall', 'user_name', 'phone', 'payment_method', 'status', 'purpose',
    'extras', 'people_count', 'amount', 'prepaid', 'booking_date', 'start_h', 'end_h',
    'timeout', 'comment', 'promo_code', 'dur_h', 'utm_source', 'utm_medium', 'utm_campaign',
    'utm_content', 'utm_term'
]
df_moloko.columns = col_name
df_luce.columns = col_name

# %% [markdown]
# ### Объединение таблиц
#
# После переименования столбцов обе таблицы (df_moloko и df_luce) стали структурно идентичны. Теперь можно объединить их в один датафрейм, который будет использоваться для всего дальнейшего анализа.

# %%
# 3. Объединение всех таблиц в одну
df_main = pd.concat([df_moloko, df_luce], ignore_index=True)

# 4. Убираем технические записи: user_name = 'Скородумова' (рабочая заглушка)
df_main = df_main[~df_main['user_name'].str.replace('C', 'С').str.contains('Скородумова', na=False)].reset_index()

# 5. Сохранение результата
df_main.to_csv('dataset/studio_data.csv', index=False)

df_main.sample(3)
# Out:
#        index       id    location     hall           user_name  \
# 10618  14005  2919517  Moloko 2.0  Большой       Дарья Казнова
# 2216    2917  2112566      Moloko     Дзен     Надежда Рожкова
# 8127   10825  2611946  Moloko 2.0  Большой  Анастасия Романова
#
#                   phone payment_method         status     purpose extras  \
# 10618  +7 929 911 11 49  Онлайн оплата  Забронировано  Фотосъемка    NaN
# 2216   +7 968 097 65 75  Онлайн оплата      Завершено  Фотосъемка    NaN
# 8127   +7 915 353 53 55  Онлайн оплата      Завершено  Фотосъемка    NaN
#
#        people_count  amount  prepaid booking_date  start_h  end_h  \
# 10618          2.00    2200     1100   11.05.2025       15     16
# 2216           2.00    2000     1000   14.10.2023       14     15
# 8127           4.00    7400     3700   22.10.2024        8     12
#
#                 timeout                                         comment  \
# 10618  06.05.2025 16:24                                             NaN
# ...

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10661 entries, 0 to 10660
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           10661 non-null  int64
#  1   id              10661 non-null  int64
#  2   location        10661 non-null  object
#  3   hall            10661 non-null  object
#  4   user_name       10661 non-null  object
#  5   phone           10661 non-null  object
#  6   payment_method  10661 non-null  object
#  7   status          10661 non-null  object
#  8   purpose         10661 non-null  object
#  9   extras          2098 non-null   object
#  10  people_count    10649 non-null  float64
#  11  amount          10661 non-null  int64
#  12  prepaid         10661 non-null  int64
#  13  booking_date    10661 non-null  object
#  14  start_h         10661 non-null  int64
#  15  end_h           10661 non-null  int64
#  16  timeout         10661 non-null  object
# ...

# %% [markdown]
# - Объединённый датафрейм содержит 10 661 запись и 25 колонок. Большинство полей заполнены полностью, но есть отдельные колонки с пропущенными значениями.
#
# - Ключевые поля (booking_date, hall, amount, dur_h, start_h, status) заполнены полностью — можно переходить к анализу и моделям.
#
# - Пропуски в extras и comment логичны и не требуют обработки.
#
# - Поля utm_source и подобные можно удалить как неинформативные.
#
# - Поле promo_code стоит оставить только если будет фокус на маркетинговых активностях — иначе его тоже можно удалить.

# %% [markdown]
# ### Распределение значений ключевых признаков
# На этом этапе анализируем распределения по категориальным полям, чтобы:
# - оценить частоту использования локаций, залов, методов оплаты и статусов заказов;
# - выявить дисбаланс в данных (например, редко используемые залы);
# - понять, какие сегменты необходимо анализировать подробнее.

# %%
#Параметры для построения графиков
list_param = [
    'location', 'hall', 'status', 'purpose',
    'people_count', 'amount',  'start_h', 'dur_h'
]

#Наименования параметров для построения графиков
list_name_param = [
    'Локация', 'Зал',  'Статус', 'Тип съемки',
    'Количестов людей', 'Оплата',  'Время начала', 'Продолжительность'
]
#Заголовок листа
suptitle = 'Распределение значений'

#Построение графиков
hist_graph (df_main,list_param,list_name_param , suptitle)

# %% [markdown]
# **Локации и Залы:**
# Самая загруженная локация — Moloko (более 2/3 всех бронирований).
# Luce Studio используется гораздо реже.
# По залам лидирует «Дзен» и «ЧБ» — на них приходится большая часть съёмок.
# Залы Grigio и Bianco — почти не используются → возможен вывод из аренды или перезапуск с другим позиционированием.
#
# **Оплата и Статусы:**
# 95% клиентов платят онлайн — удобно, безопасно, экономит время.
# Основной статус — «Завершено», но есть значительная доля отменённых и просроченных бронирований, с которыми стоит работать (например, напоминания, депозиты, фильтр «ненадёжных»).
#
# **Тип съёмки и поведение клиентов:**
# Почти все бронирования — фотосъёмки, видеосъёмки — единичны. Это может быть точкой роста (предложить спецпакеты для видео?).
# Обычно приходит 1–2 человека.
# Чаще всего бронируют 1–2 часа, иногда — до 3–4.
# Начинают снимать чаще всего в интервале с 11:00 до 15:00 (пик в районе 13:00).
#
# **Деньги:**
# Большинство съёмок — на средние чеки (2000–4000₽).
# Предоплата чаще всего соответствует половине стоимости — стандартная и, судя по всему, приемлемая схема.

# %% [markdown]
# ## Исследовательский анализ данных.
# В этом разделе мы проводим глубокий анализ ключевых признаков, формируем новые поля, визуализируем поведение пользователей и выявляем скрытые зависимости между залами, днями недели и доходностью.
#
# ---
#
# **1. Добавление признаков: Год, Месяц, День недели, Расходы и Приведённая аренда**
#
# Для временного и ценового анализа создаём следующие поля:
#
# * `year`, `month`, `weekday` — извлечены из даты бронирования;
# * `extras_cost` — стоимость всех дополнительных услуг;
# * `rent_estimate` — стандартная стоимость аренды по текущим ставкам (без скидок и инфляции);
# * `base_rent` — фактическая цена аренды, которую заплатил клиент (без доп.услуг);
# * это позволяет сравнивать заказы между собой, **независимо от времени**.
#
# ---
#
# **2. Анализ клиентов**
#
# **Цель** — выделить:
#
# * ядро аудитории — кто бронирует регулярно;
# * постоянных клиентов — по числу заказов;
# * крупных заказчиков — по общей сумме или длительности аренды.
#
# Разделим пользовательей на группы по:
#
# * количество бронирований;
# * суммарную выручку;
# * среднюю продолжительность;
#
# -> Выводится **рейтинг клиентов** и считается доля "ядра" (например, 20% клиентов приносят 70% выручки).
#
# ---
#
# **3. Анализ залов и сезонности**
#
# **Сезонность и тренды**
#
# * Помесячная динамика аренды и дохода по каждому залу;
# * Построены **линейные графики** загрузки и выручки со скользящим средним.
#
# **Заполняемость по часам и дням недели**
#
# * Построим **тепловую карту**, в какие часы залы максимально загружены;
# * Выявить **"мёртвые зоны"** — периоды, когда залы простаивают.
#
#
# ---
#
# **4. Дополнительные услуги**
#
# Проведём разбор поля `extras`:
#
# * парсинг всех упоминаний вида `услуга x кол-во`;
# * очистку и нормализация названий;
# * добавляем реальные цены;
# * рассчитываем **общую выручку по каждой услуге**.

# %% [markdown]
# ### Дополнительные признаки

# %% [markdown]
# **Дополнительные расходы**
#
# Расчёт стоимости дополнительных услуг
# В поле extras содержится строка с перечнем доп.услуг в формате "гримерная x 1", "проектор x 2" и т.п.
# с помощью регулярных выражений ищем совпадения;
# умножаем количество на цену и получаем итоговую сумму.
# Результат записывается в новый столбец extras_cost.

# %%
# Справочник цен на дополнительные услуги (в рублях)
extras_prices = {
    "гримерная": 300,
    "проектор": 500,
    "дым-машина": 300,
    "инструктаж по свету": 1500,
    "журавль стойка": 300,
    "ассистент на съёмку": 500,
    "бумажный фон": 500,
    "покраска циклорамы": 1000
}

# Нормализация строки: удаляем лишние пробелы, приводим к нижнему регистру
def normalize(text):
    return re.sub(r'\s+', ' ', text.strip().lower())

# Основная функция: извлекает и суммирует стоимость всех доп.услуг
def calculate_extras_cost_robust(extras_str):
    if pd.isna(extras_str):
        return 0
    extras_str = normalize(extras_str)
    total = 0
    for service_key, price in extras_prices.items():
        pattern = rf"{re.escape(service_key)}\s*x\s*(\d+)"   # ищем "услуга x кол-во"
        match = re.search(pattern, extras_str)
        if match:
            total += int(match.group(1)) * price
    return total

# Применяем функцию ко всему датафрейму
df_main['extras_cost'] = df_main['extras'].apply(calculate_extras_cost_robust)

# %% [markdown]
# **Год, день недели, месяц. Нормализованная аренда**
#
# Для временного анализа и устранения влияния инфляции:
#
# 1. Из даты бронирования извлекаем:
#    * `year` — год;
#    * `month` — месяц;
#    * `weekday` — день недели (текстом);
#    * `week` — номер недели (для недельных моделей).
#
# 2. Вычисляем **фактическую стоимость аренды** без учёта дополнительных услуг:
#
#    Это значение показывает, сколько клиент реально платил **за 1 час аренды**, и позволяет:
#
#    * сравнивать заказы между собой в разные периоды;
#    * выявлять момент повышения цен;
#    * построить тренд по росту стоимости аренды и его связь с падением спроса.

# %%
# Преобразуем дату бронирования
df_main["booking_date"] = pd.to_datetime(df_main["booking_date"], format="%d.%m.%Y", errors='coerce')
# Оставляем только завершенные бронирования.
df_main= df_main[df_main['status']=='Завершено']
# Оставляем только бронирования с 9:00 - 22:00.
df_main= df_main[df_main['start_h']>=9]


# Извлекаем календарные признаки
df_main["weekday"] = df_main["booking_date"].dt.day_name()
df_main["month"] = df_main["booking_date"].dt.month
df_main["year"] = df_main["booking_date"].dt.year


# Базовые тарифы (будни, выходные)
hall_rates = {
    "Bianco": (1600, 1800),
    "Grigio": (1600, 1800),
    "ЧБ": (1800, 1800),
    "Дзен": (1800, 1800),
    "Малый": (1800, 1800),
    "Большой": (2000, 2200)
}

# Расчёт стоимости аренды
def calculate_rent(row):
    hall = str(row["hall"])
    duration = row["dur_h"]
    weekday = row["weekday"]

    if pd.isna(duration) or hall not in hall_rates:
        return None

    is_weekend = weekday in ["Saturday", "Sunday"]
    rate = hall_rates[hall][1] if is_weekend else hall_rates[hall][0]
    return rate * duration

# Применяем функцию
df_main["rent_estimate"] = df_main.apply(calculate_rent, axis=1)

# %% [markdown]
# ** Примеры работы алгоритмы по выделению дополнительных услуг и их стоимости **
#
# В таблице видно, что расчёты работают корректно:
# * `"Гримерная x 3"` даёт `900 ₽`;
# * `"бумажный фон x 2"` — `1000 ₽`;
# * `"дым-машина x 1"` — `300 ₽` и т.д.
#
# Всего зафиксировано **1414 заказов с доп.услугами**, что составляет \~13% всех бронирований — это заметная доля, которая оказывает влияние на выручку.
# Позже эти данные будут использованы для анализа популярности и прибыльности отдельных услуг.

# %%
df_main[['extras_cost','extras']][df_main['extras_cost']>0]
# Out:
#        extras_cost            extras
# 0              300    Гримерная  x 1
# 21             900    Гримерная  x 3
# 23             300    Гримерная  x 1
# 26             300    Гримерная  x 1
# 35             600    Гримерная  x 2
# ...            ...               ...
# 10515          300    дым-машина x 1
# 10530          500  бумажный фон x 1
# 10550          300    дым-машина x 1
# 10554         1000  бумажный фон x 2
# 10587          500  бумажный фон x 1
#
# [1414 rows x 2 columns]

# %%
# 5. Сохранение результата
df_main.to_csv('dataset/studio_data_anc.csv', index=False)

# %% [markdown]
# ### Phik корелляция
#
# Корреляционный анализ с помощью Phik-корреляции (Phi-корреляции) — универсального метода для оценки связей между переменными любой природы: числовыми, категориальными и смешанными.
# В отличие от стандартных коэффициентов (Pearson, Spearman), phik корректно работает и с нечисловыми данными, не требует кодирования и устойчив к пропускам.

# %%
col_phik = [ 
    'amount', 'extras_cost' , 'dur_h',
    'hall', 'user_name', 'people_count', 'prepaid', 
    'month', 'weekday', 'start_h' 
]

# считаем корреляции на тренировочной выборке
phik_overview = phik_matrix(df_main[col_phik].sample(3000), interval_cols = ['amount', 'extras_cost','prepaid'] )

plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
);

# %% [markdown]
# **Выводы из φK-корреляционной матрицы**
#
# * **Сильные положительные связи:**
#
#   * `user_name ↔ people_count` (0.97), `user_name ↔ prepaid` (0.83), `user_name ↔ amount` (0.87)
#     → постоянные клиенты чаще делают более крупные и оплаченные заказы.
#   * `prepaid ↔ amount` (0.85), `prepaid ↔ dur_h` (0.89)
#     → чем больше сумма и длительность аренды — тем выше вероятность предоплаты.
#   * `dur_h ↔ amount` (0.90) — логичная зависимость: чем дольше аренда, тем выше сумма.
#
# * **Связь с залом (`hall`)**
#
#   * `hall ↔ user_name` (0.91) — у пользователей есть любимые залы;
#   * `hall ↔ month` (0.25) — сезонная востребованность разных залов.
#
# * **Слабая или отсутствующая связь:**
#
#   * `weekday` почти не влияет ни на один из количественных признаков — возможен равномерный спрос по дням недели;
#   * `start_h` слабо коррелирует с `amount`, но умеренно с `user_name` — возможно, некоторые клиенты бронируют определённые часы.

# %% [markdown]
# ### Анализ клиентов
#
# **Рейтинг по сумме аренды**
#
# На этом этапе мы агрегируем данные по каждому клиенту (по имени и телефону) и рассчитываем ключевые показатели:
#
# * **`dur_med`** — медианная продолжительность аренды (в часах);
# * **`sum_cost`** — суммарные расходы на дополнительные услуги;
# * **`people_med`** — медианное количество участников съёмки;
# * **`count_rent`** — общее количество бронирований;
# * **`sum_rent`** — суммарная выручка от аренды залов (без учёта доп.услуг).
#
# В таблице `pivot_sorted.head(5)` — **топ-5 самых прибыльных клиентов**. Эти пользователи составляют ядро аудитории и могут быть целевой группой для лояльности, бонусов или персональных предложений.

# %%
pivot = df_main.pivot_table(
    index=['user_name', 'phone'],
    values=['rent_estimate','extras_cost', 'dur_h', 'people_count'],
    aggfunc={ 'dur_h':['median'], 'extras_cost':['sum'], 'people_count':['median'], 'rent_estimate':['count', 'sum']}
).reset_index()

# Переименуем колонки для удобства
pivot.columns = ['user_name', 'phone','dur_med', 'sum_cost', 'people_med', 'count_rent', 'sum_rent']

# Сортировка по сумме
pivot_sorted = pivot.sort_values('sum_rent', ascending=False)

pivot_sorted.head(5)
# Out:
#                   user_name             phone  dur_med  sum_cost  people_med  \
# 1131         Андрей Миронов  +7 967 244 34 84     2.00         0        3.00
# 1779    Вероника Сержантова  +7 925 170 11 44     2.00         0        1.00
# 4470         Ника Бестужева  +7 909 939 93 09     3.00         0        1.00
# 2191        Дарья Клепикова  +7 929 671 63 55     2.00      5000        1.00
# 184   Айгузель Амангильдина  +7 925 356 88 48     1.00      1300        3.00
#
#       count_rent  sum_rent
# 1131          64    245800
# 1779          28    107200
# 4470          22    104400
# 2191          30    102000
# 184           35     81400

# %% [markdown]
# **Доля прибыльных клиентов**
# Задача этого этапа — определить, какое количество клиентов приносит наибольшую долю выручки, и визуализировать соотношение с помощью круговой диаграммы.
# Выделяются топ-клиенты, которые в сумме приносят 25% выручки;

# %%
# 1. Добавляем долю в прибыли
pivot_sorted["cum_rent"] = pivot_sorted["sum_rent"].cumsum() / pivot_sorted["sum_rent"].sum()

# Вычисления как раньше
top_clients_30 = pivot_sorted[pivot_sorted["cum_rent"] <= 0.25]
n_top_clients = len(top_clients_30)
total_clients = len(pivot_sorted)
other_clients = total_clients - n_top_clients

# Данные для круговой диаграммы
sizes = [top_clients_30["sum_rent"].sum(), pivot_sorted["sum_rent"].sum() - top_clients_30["sum_rent"].sum()]
labels = [f'Топ {n_top_clients} клиентов', f'{other_clients} остальных']
colors = ['green', 'gray']

# Построение круговой диаграммы
fig, ax = plt.subplots(figsize=(6, 6))
wedges, texts, autotexts = ax.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    textprops={'fontsize': 12}
)

# Добавим количество клиентов внутри секторов
for i, wedge in enumerate(wedges):
    ang = (wedge.theta2 + wedge.theta1) / 2
    x = wedge.r * 0.5 * np.cos(np.deg2rad(ang))
    y = wedge.r * 0.5 * np.sin(np.deg2rad(ang))
    client_count = n_top_clients if i == 0 else other_clients
    ax.text(x, y, f'{client_count}', ha='center', va='center', fontsize=12, color='white', weight='bold')

ax.set_title('Доля выручки и количество клиентов', fontsize=14)
plt.tight_layout()

plt.show()

# %% [markdown]
# Небольшая группа клиентов (в нашем случае — примерно 25% выручки дают всего N клиентов) формирует значимую долю дохода;
# Это ядро аудитории, с которым стоит работать точечно: программы лояльности, спецпредложения, приоритетные слоты;
# Остальная масса клиентов менее ценна в финансовом выражении, но может быть перспективной для масштабирования.

# %% [markdown]
# **Кластеризация клиентов по профилю бронирований**
# Цель этого анализа — сегментировать клиентов на осмысленные группы, чтобы в будущем:
# - давать таргетированные предложения;
# - понимать, кто приносит больше денег;
# - оценивать поведение разных типов клиентов.

# %%
pivot_sorted = pivot_sorted[pivot_sorted['sum_rent'] <150000] 
# 1. Выбор признаков
features = pivot_sorted[["dur_med", "sum_cost", "people_med", "count_rent", "sum_rent"]].fillna(0)

# 2. Нормализация
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)

# 3. Кластеризация
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
pivot_sorted["cluster"] = kmeans.fit_predict(X_scaled)

# 4. Сводка по кластерам
# Средние значения по кластерам
cluster_means = pivot_sorted.groupby("cluster")[["dur_med", "sum_cost", "people_med", "count_rent", "sum_rent"]].mean().round(1)
cluster_means.columns = ['dur','cost','people','rent_count','rent_amount']

# Количество клиентов в каждом кластере
cluster_counts = pivot_sorted.groupby("cluster").size().rename("client_count")

# Объединяем
cluster_summary = pd.concat([cluster_counts, cluster_means], axis=1)
display(cluster_summary)

# 5. Визуализация
plt.figure(figsize=(10, 6))
sns.boxplot(data=pivot_sorted, x="cluster", y="sum_rent", palette="Set2")
plt.title("Распределение выручки по кластерам")
plt.xlabel("Кластер")
plt.ylabel("Суммарная аренда (₽)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#          client_count  dur     cost  people  rent_count  rent_amount
# cluster
# 0                1384 2.50   137.10    3.80        1.40     6,075.90
# 1                4288 1.30    69.20    1.80        1.30     3,128.20
# 2                 127 1.70 1,491.30    2.00       11.10    32,407.90

# %% [markdown]
# Можно условно интерпретировать:
# - Кластер 0 — «микро-клиенты», редкие заказы, низкий чек;
#
# - Кластер 1 — «средний сегмент», регулярные, но недорогие съёмки;
#
# - Кластер 2 — «ключевые клиенты», часто заказывают и приносят основную выручку.
#
# **Вывод по сегментам: потенциал роста и удержание**
#
# Результаты кластеризации показывают, что:
#
# * **Кластер 2** — это ключевые клиенты с высокой выручкой и регулярными съёмками;
# * **Кластер 1** — активный, но менее доходный сегмент, который часто снимает, но на меньшие суммы.
#
# **Если удастся перевести хотя бы 10% клиентов из Кластера 1 в поведение Кластера 2 — выручка может вырасти на 25%** без привлечения новых клиентов.
#
# ---
#
# **Рекомендации:**
#
# * **Фокус на удержание Кластера 1**:
#
#   * абонементы на 3/5/10 съёмок;
#   * приоритетная бронь в пиковые часы;
#   * программа лояльности на любимый зал;
#   * кросс-продажи: скидка на доп.услуги при повторной съёмке в течение месяца.
#
# * **Продвижение внутрь бренда**:
#   Сделать так, чтобы эти клиенты не искали другие студии, а **снимали чаще у вас**, даже если чек останется прежним.
#
# ---
#
# Такой подход даст органичный рост без необходимости тратить бюджет на холодный маркетинг.

# %% [markdown]
# ### Анализ залов

# %% [markdown]
# ** Динамика дохода по залам (по `amount`)**
#
# Анализируем **помесячную выручку по каждому залу** на основе поля `amount` — это сумма, которую реально внёс клиент. Она включает:
# * стоимость аренды;
# * доп.услуги;
# * предоплаты и возможные скидки.
# Для сглаживания сезонных колебаний применено **скользящее среднее с окном в 3 месяца**.

# %%
# 1. Загрузка данных
#df = pd.read_csv("studio_data_anc.csv", parse_dates=["booking_date"])

# 2. Фильтрация и подготовка
df = df_main # df[df["booking_date"].notna()]
df["year_month"] = df["booking_date"].dt.to_period("M").astype(str)

# 3. Помесячный доход по залам
monthly_rent = df.pivot_table(
    index="year_month",
    columns="hall",
    values="amount",
    aggfunc="sum"
).fillna(0)

# 4. Скользящее среднее (3 месяца)
monthly_rent_smooth = monthly_rent.rolling(window=3, min_periods=1).mean()

# 5. Визуализация
plt.figure(figsize=(12, 6))
for hall in monthly_rent_smooth.columns:
    plt.plot(monthly_rent_smooth.index, monthly_rent_smooth[hall], label=hall, linewidth=2)

plt.title("Доход по аренде (amount) со скользящим средним")
plt.xlabel("Месяц")
plt.ylabel("Суммарный доход, ₽")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title="Зал")
plt.tight_layout()
plt.show()

# %% [markdown]
# * Чётко видны моменты **запуска новых залов** и **точки роста выручки**;
# * Наблюдается **общий тренд к росту дохода**;
# * При этом ранее мы уже установили, что **количество арендованных часов при этом падает** — значит, выручка растёт не за счёт спроса, а:
#
#   * за счёт **повышения цен**;
#   * за счёт **расширения площадей** (новые залы);
#   * частично — за счёт доп.услуг.

# %% [markdown]
# **Динамика заполняемости залов (по часам в месяц)**
#
# В этом блоке мы анализируем **фактическое количество занятых часов** по каждому залу в разрезе месяцев. Это отражает **реальную активность клиентов** и используется для сравнения с динамикой выручки.

# %%
# 3. Количество занятых часов по залам
monthly_hours = df.groupby(["year_month", "hall"]).size().unstack().fillna(0)

# 4. Скользящее среднее (3 месяца)
monthly_hours_smooth = monthly_hours.rolling(window=3, min_periods=1).mean()

# 5. Визуализация
plt.figure(figsize=(12, 6))
for hall in monthly_hours.columns:
    plt.plot(monthly_hours_smooth.index, monthly_hours_smooth[hall], label=f"{hall} (сглажено)", linewidth=2)

plt.title("Заполняемость залов (часов в мес)")
plt.xlabel("Месяц")
plt.ylabel("Занятые часы")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title="Зал", ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# График отражает **скользящее среднее по часам аренды** для каждого зала, сгруппированное помесячно. Это позволяет оценить **реальную активность** по залам без сезонных шумов и разовых всплесков.
#
# ---
#
# 1. **Зал "Дзен"** — лидер по загрузке в первой половине 2023 года, достигает пика в апреле (\~175 ч/мес), но затем показывает **постепенное и устойчивое снижение**. Это первый сигнал возможного **насыщения или усталости аудитории**.
#
# 2. **"ЧБ" и "Малый" залы** стали основными драйверами с конца 2023 — при этом они не достигли показателей "Дзена", но обеспечили **новую волну загрузки** в студии.
#
# 3. В середине 2024 года появляется **"Большой" зал**, который быстро набирает обороты и к весне 2025 года становится одним из самых стабильных по загрузке.
#
# 4. **"Bianco" и "Grigio"** — новички, вышедшие на рынок только в конце 2024. Несмотря на это, за полгода они уже показывают рост, особенно зал Bianco в начале 2025.
#
# **Общий тренд:**
#
# * В целом, **нагрузка распределяется на бОльшее количество залов**, но при этом **ни один не достигает пиковых значений "Дзена"** прошлого года;

# %% [markdown]
# **Тренд стоимости аренды и загрузки залов**
#
# Анализируем только **залы, работающие более года**:
# `"Дзен"`, `"ЧБ"`, `"Малый"` и `"Большой"` — это даёт более достоверную картину, без искажений от новых залов.
# - Фильтруем бронирования с марта 2023 года по 4 ключевым залам;
# - Группируем по залу и месяцу, а затем усредняем по всем залам:
#    * получаем **среднюю цену за час**; - красная линия
#    * получаем **среднее количество часов аренды в месяц**;  синие линии

# %%
# Перерасчёт тренда, если данные были утеряны
selected_halls = ["Дзен", "ЧБ", "Малый", "Большой"]
df = df_main[
    (df_main["hall"].isin(selected_halls)) &
    (df_main["booking_date"] >= "2023-03-01") &
    (df_main["dur_h"] > 0)
].copy()

df["base_rent"] = (df["amount"] - df["extras_cost"]) / df["dur_h"]
df["year_month"] = df["booking_date"].dt.to_period("M").astype(str)

df_tr = df.groupby(["hall","year_month"]).agg({
    "base_rent": "mean",
    "dur_h": "sum"
}).rename(columns={
    "base_rent": "base_rent",
    "dur_h": "dur_h"
}).dropna()

df_trend = df_tr.groupby(["year_month"]).agg({
    "base_rent": "mean",
    "dur_h": "mean"
}).rename(columns={
    "base_rent": "avg_price_per_hour",
    "dur_h": "total_hours"
}).dropna()

# Добавим скользящие средние
df_trend["avg_price_smooth"] = df_trend["avg_price_per_hour"].rolling(window=3, min_periods=1).mean()
df_trend["total_hours_smooth_3"] = df_trend["total_hours"].rolling(window=3, min_periods=1).mean()
df_trend["total_hours_smooth_6"] = df_trend["total_hours"].rolling(window=9, min_periods=1).mean()

# Визуализация
fig, ax1 = plt.subplots(figsize=(12, 6))

# Красная линия — цена за час (3 мес сглаживание)
ax1.set_xlabel("Месяц")
ax1.set_ylabel("Средняя цена за час (₽)", color="tab:red")
ax1.plot(df_trend.index, df_trend["avg_price_smooth"], label="Цена (3 мес)", color="tab:red", linewidth=2)
ax1.tick_params(axis='y', labelcolor="tab:red")
ax1.set_xticklabels(df_trend.index, rotation=45)

# Синие линии — часы аренды (3 мес и 6 мес сглаживание)
ax2 = ax1.twinx()
ax2.set_ylabel("Суммарные часы аренды", color="tab:blue")
ax2.plot(df_trend.index, df_trend["total_hours_smooth_3"], label="Часы (3 мес)", color="tab:blue", linestyle='dotted', linewidth=2)
ax2.plot(df_trend.index, df_trend["total_hours_smooth_6"], label="Часы (6 мес)", color="tab:blue", linewidth=2)
ax2.tick_params(axis='y', labelcolor="tab:blue")

plt.title("Дзен, ЧБ, Малый, Большой: Цена за час vs Часы аренды (3 и 6 мес сглаживание)")
fig.tight_layout()
plt.grid(True)
plt.show()

# 5. Сохранение результата
df_trend.to_csv('dataset/trend_data.csv', index=False)

# %% [markdown]
# * С весны 2023 года наблюдается **постоянный рост средней почасовой ставки аренды**;
# * Одновременно с этим происходит **снижение количества часов аренды на зал** ;
# * Скользящее среднее на 6 месяцев показывает **стабильный тренд на падение активности**, несмотря на расширение площадок;
# * То есть:
#   📉 **посещаемость падает**,
#   📈 но **средний чек растёт** → это и обеспечивает рост общей выручки.
#
# 📌 График наглядно подтверждает ключевую гипотезу:
#
# > **Финансовый рост студии обеспечивается не за счёт увеличения спроса, а за счёт повышения цен и открытия новых залов.**

# %% [markdown]
# ** Корреляция между ценой и загрузкой**
#
# Для оценки того, как **изменение цены влияет на посещаемость**, рассчитаны `φK`-корреляции между:
#
# * `avg_price_per_hour` — фактическая средняя цена за час;
# * `avg_price_smooth` — сглаженная цена (rolling 3 месяца);
# * `total_hours`, `total_hours_smooth_3` — суммарные часы аренды и сглаженная нагрузка.

# %%
##Корелляция посещаемости и стоимости аренды
col_phik = ['avg_price_per_hour', 'avg_price_smooth',  'total_hours_smooth_3',   "total_hours"]

# считаем корреляции 
phik_overview = phik_matrix(df_trend[col_phik], interval_cols = ['avg_price_smooth', 'total_hours_smooth_3', 'avg_price_per_hour', "total_hours"] )

plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    figsize=(10, 8)
);

# %% [markdown]
# * Между ценой и загрузкой **наблюдается умеренно отрицательная корреляция**:
#   * `φK ≈ 0.49–0.61` между `avg_price_*` и `total_hours_*`
#   * это означает, что **рост цен сопровождается снижением количества часов аренды**, но не жёстко — связь **не линейная**, что логично для бизнеса с сезонностью и пиковыми часами.
#
# **Интерпретация:**
#
# > При повышении цены **загрузка действительно снижается**,
# > но не критично — клиенты продолжают снимать,
# > особенно если цена повышается **умеренно и постепенно**.
#
# Этот результат показывает, что **повышение цен — управляемый инструмент**.

# %% [markdown]
# **Тепловая карта загруженности по часам и дням недели**
# (данные за октябрь–апрель, все залы)
#
# Тепловая карта позволяет наглядно увидеть, в какие часы и в какие дни недели залы наиболее востребованы.

# %%
# Загрузка и подготовка
df = df_main

# Расширение строк по часам бронирования
rows = []
for _, row in df.iterrows():
    for hour in range(int(row["start_h"]), int(row["start_h"] + row["dur_h"])):
        rows.append({
            "weekday": row["weekday"],
            "hour": hour
        })

df_hours = pd.DataFrame(rows)

# Создаём тепловую таблицу
heat_data = df_hours.pivot_table(
    index="hour", columns="weekday", aggfunc="size", fill_value=0
)

# Упорядочим дни недели
weekday_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
heat_data = heat_data[weekday_order]

# Отрисовка
plt.figure(figsize=(12, 6))
sns.heatmap(heat_data, cmap="YlGnBu", linewidths=.5, annot=True, fmt=".0f")
plt.title("Тепловая карта - популярные часы.")
plt.xlabel("День недели")
plt.ylabel("Час")
plt.tight_layout()
plt.show()

# %% [markdown]
# На основе тепловых карт и анализа активности по часам и месяцам можно выделить устойчивые поведенческие шаблоны клиентов.
#
# **Основные наблюдения:**
#
# * **Явная сезонность**:
#   С октября по март — высокий спрос,
#   с мая по август — спад (многие снимают на улице).
#
# * **Выходные заметно активнее будней**, особенно суббота и воскресенье после обеда.
#
# * **Средняя заполняемость** (из расчёта 390 доступных часов в месяц на зал):
#   * зимой — **до 50%**;
#   * летом — **падает до 20%**.
#
# * **Часовая активность**:
#
#   * Пик — с **12:00 до 16:00**, особенно в выходные;
#   * После 19:00 активность резко снижается;
#   * **Утренние часы (до 11:00)** — consistently слабые;
#   * Понедельник — **наименее загруженный день**.
#
# **Выводы:**
#
# * Самый востребованный слот недели — **воскресенье, 14:00**;
# * По будням утром и вечером залы почти не используются;
# * Вечерний спад после пятницы — закономерен, активность в субботу выше, чем в воскресенье.
#
# **Рекомендации:**
#
# * **Будни до 11:00 и после 20:00** — ввести **антиспросовые скидки**, возможно — отдельные "утренние пакеты";
# * В пиковые слоты — рассмотреть **повышение цены** или выделение таймслотов только для **постоянных клиентов/абонементов**;
# * Летний спад, судя по тренду, **не компенсируется промоакциями** — лучше использовать это время для съёмок вне студии, партнёрств, ремонта или обновления залов.

# %% [markdown]
# ### Анализ дополнительных услуг
#
# Дополнительные услуги — это важная статья дохода фотостудии. Их анализ позволяет:
# - понять, на чём зарабатывают чаще всего;
# - определить услуги для усиленного продвижения;
# - пересмотреть ценовую стратегию и сформировать выгодные пакеты.

# %%
from collections import Counter

df = df_main
df["extras"] = df["extras"].fillna("")

# Паттерн: "Название x Число"
pattern = r"([А-Яа-яA-Za-z\s\.\-]+?)\s*x\s*(\d+)"
service_counter = Counter()
service_total_value = Counter()

# Простой парсинг услуг
for i, row in df.iterrows():
    matches = re.findall(pattern, row["extras"])
    for name, qty in matches:
        name_clean = name.strip().lower()
        quantity = int(qty)
        service_counter[name_clean] += quantity
        service_total_value[name_clean] += quantity  # стоимость пока временная

# Преобразуем в таблицу
services_df = pd.DataFrame({
    "service": list(service_counter.keys()),
    "total_count": list(service_counter.values()),
    "total_value_placeholder": list(service_total_value.values())
}).sort_values("total_count", ascending=False).reset_index(drop=True)

#import ace_tools as tools; tools.display_dataframe_to_user(name="Анализ дополнительных услуг", dataframe=services_df)
services_df.head()
# Out:
#           service  total_count  total_value_placeholder
# 0       гримерная         1209                     1209
# 1            рная          399                      399
# 2      дым-машина          314                      314
# 3             рка          257                      257
# 4  журавль стойка          112                      112

# %%
# 1. Очистка названий услуг и замена обрезанных версий на корректные
replace_map = {
    "рная": "гримерная",
    "рка": "гримерная",
    "гримерка": "гримерная",
    "инструктаж по свету": "инструктаж по свету",
    "ассистент на съёмку": "ассистент",
    "журавль стойка": "журавль",
    "бумажный фон": "фон",
    "проектор": "проектор",
    "дым-машина": "дым-машина"
}

# Удалим пробелы и приведем к нижнему регистру
services_df["service_clean"] = services_df["service"].str.strip().str.lower()
services_df["service_clean"] = services_df["service_clean"].replace(replace_map)

# 2. Добавим цены для расчёта выручки
price_map = {
    "гримерная": 300,
    "покраска циклорамы": 1000,
    "проектор": 500,
    "инструктаж по свету": 1500,
    "журавль": 300,
    "ассистент": 500,
    "фон": 500,
    "дым-машина": 300
}

services_df["price"] = services_df["service_clean"].map(price_map)
services_df["total_revenue"] = services_df["total_count"] * services_df["price"]

# 3. Группируем по очищенным названиям
grouped = services_df.groupby("service_clean").agg({
    "total_count": "sum",
    "total_revenue": "sum"
}).sort_values("total_revenue", ascending=False).reset_index()


grouped = grouped.head(7)

# 4. Визуализация
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(grouped["service_clean"], grouped["total_revenue"], color="teal")
plt.xlabel("Доход по услуге (₽)")
plt.ylabel("Услуга")
plt.title("ТОП дополнительных услуг по выручке")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# * **Гримерная** — уверенный лидер как по частоте, так и по выручке: более 1200 заказов и почти **полмиллиона рублей**;
# * Также популярны:
#
#   * **покраска циклорамы** — редкая, но дорогая;
#   * **проектор**, **инструктаж по свету**, **фон**, **журавль**, **дым-машина** — регулярные, но с меньшим вкладом;
# * Ошибки в исходных строках (`рка`, `рная`) составляют более 500 записей и без очистки привели бы к недооценке выручки.
#
# **Рекомендации:**
# * Предложить **пакеты услуг**: "Гримерная + ассистент", "Инструктаж + свет" и т.д.;
# * Внедрить **upsell**: при бронировании автоматически предлагать самые заказываемые позиции;
#
# * **Приоритизировать поддержку и обновление** оборудования, связанного с топ-услугами;
#
# ---

# %% [markdown]
# ### Выводы - Исследовательский анализ.
#
# 1. **Загрузка залов**
#
# * Залы **Дзен** и **ЧБ** стабилизировали загрузку к марту 2023 года.
# * Суммарное количество арендованных часов **постепенно снижается**, особенно по сравнению с аналогичными периодами предыдущих лет.
# * При этом **доход остаётся стабильным или растёт**, что указывает на **повышение цен**.
#
# 2. **Ценообразование**
#
# * Анализ поля `amount` показывает, что **средняя почасовая ставка** заметно увеличилась в течение 2023 года.
# * После повышения цены наблюдается **корреляция с падением количества арендованных часов** (обратная зависимость).
# * Однако **суммарная выручка не страдает** — гипотеза о том, что повышение цен компенсировало снижение загрузки, подтверждается.
#
# 3. **Дополнительные услуги**
#
# * Абсолютный лидер по популярности и выручке — **гримерная**.
# * Также востребованы: **покраска циклорамы**, **проектор**, **дым-машина**.
# * Есть ошибки и артефакты в исходных названиях (`рка`, `рная`), что повлияло на чистоту данных — исправлено.
#
# ---
#
#  **Рекомендации и гипотезы для проверки**
#
# Ценообразование
#
# * **Фиксировать изменение ставок** (ввести гибкую таблицу по дням недели и залам);
# * **Проверить порог чувствительности** — в какой момент снижение загрузки превышает рост цены;
# * Провести **A/B-анализ по цене** (если возможно).
#
# Дополнительные услуги
#
# * Разработать **пакетные предложения** (например, "гримерная + свет + ассистент");
# * Продвигать **самые прибыльные услуги** при онлайн-бронировании (подсветка, upsell);
# * Подумать о **динамическом ценообразовании** (например, у покраски — цена по срочности).
#
# Операционное планирование
#
# * На основе тепловых карт — **внедрить промо или скидки в “мёртвые часы”**;
# * **Перераспределить маркетинговый акцент** между залами в зависимости от их загрузки;
# * Использовать аналитическую панель для **мониторинга отклонений в загрузке и доходе** по залам.
#
# ---
#
# **Анализ рынка фотостудий в районе Электрозаводская**
#
# Район Электрозаводская в Москве известен высокой концентрацией фотостудий благодаря наличию просторных индустриальных помещений, подходящих для креативных пространств. Это создает конкурентную среду, где студии предлагают разнообразные услуги и ценовые предложения.
#
#  Конкуренция и ценовой диапазон
#
# Цены на аренду залов в фотостудиях района варьируются в зависимости от оснащения и времени суток. Средняя стоимость аренды составляет от 1,500 до 3,000 рублей в час. Некоторые студии предлагают скидки в непиковые часы или при длительной аренде.
#
# ---
#
# **Прогноз влияния снижения цен на загруженность залов**
#
# Снижение цен может повлиять на загруженность залов следующим образом:
#
# * **Увеличение спроса:** Более низкие цены могут привлечь клиентов с ограниченным бюджетом, увеличивая общее количество бронирований.
#
# * **Конкурентное преимущество:** Предложение более выгодных условий может выделить студию среди конкурентов, особенно в условиях высокой конкуренции.
#
# * **Риск снижения дохода:** Если увеличение количества бронирований не компенсирует снижение цены, общий доход может уменьшиться.
#
# Рекомендации
#
# * **Таргетированное снижение цен:** Рассмотрите возможность снижения цен в периоды низкой загрузки, чтобы стимулировать спрос без потери дохода в пиковые часы.
#
# * **Промоакции и пакеты услуг:** Предложите специальные предложения или пакеты услуг, чтобы увеличить средний чек и привлечь новых клиентов.
#
# * **Мониторинг конкурентов:** Следите за ценовой политикой конкурентов в районе, чтобы своевременно адаптировать свои предложения.

# %% [markdown]
# ## Прогнозирование

# %% [markdown]
# ### Прогноз общей выручки по месяцам (модель Prophet)
#
# Для оценки будущих поступлений и уверенного планирования студии построен **временной прогноз выручки** с помощью библиотеки `Prophet` от Meta.
# Модель `Prophet` обучается на исторических значениях и **строит прогноз на 9 месяцев вперёд** (до конца 2025 года);
# На графике отображается:
#
#    * 🔵 синия линия — предсказанная выручка;
#    * 🔵 зона вокруг — **доверительный интервал (95%)**;
#    * ⚫ чёрные точки — фактические значения за прошедшие месяцы.

# %%
# Подготовка данных
df = pd.read_csv("dataset/studio_data_anc.csv", parse_dates=["booking_date"])
df = df[df["booking_date"] >= "2023-03-01"].copy()
df["rent_total"] = df['amount'] #df["rent_estimate"] + df["extras_cost"]
df["year_month"] = df["booking_date"].dt.to_period("M").dt.to_timestamp()

# Агрегация по месяцам
monthly_revenue = df.groupby("year_month")["rent_total"].sum().reset_index()
monthly_revenue.columns = ["ds", "y"]

# Модель Prophet
model = Prophet()
model.fit(monthly_revenue)

# Прогноз на N-periods месяцев вперёд
future = model.make_future_dataframe(periods=9, freq='M')
forecast = model.predict(future)

# Визуализация
model.plot(forecast)
plt.title("Прогноз общей выручки 2025 (Prophet)")
plt.xlabel("Месяц")
plt.ylabel("Доход, ₽")
plt.grid(True)
plt.tight_layout()
plt.show()

# Таблица
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(6)
# Out:
# 22:03:44 - cmdstanpy - INFO - Chain [1] start processing
# 22:03:44 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower   yhat_upper
# 30 2025-08-31 1,526,425.60 1,237,790.25 1,842,588.64
# 31 2025-09-30 1,844,436.47 1,523,170.09 2,126,050.70
# 32 2025-10-31 2,137,630.01 1,847,517.72 2,437,591.24
# 33 2025-11-30 1,906,394.77 1,610,415.51 2,204,842.30
# 34 2025-12-31 2,079,587.49 1,791,343.97 2,361,081.69
# 35 2026-01-31 1,817,346.73 1,516,710.69 2,101,929.15

# %% [markdown]
# * Модель корректно улавливает **сезонный характер спроса**:
#
#   * спад в летние месяцы;
#   * рост с октября по март;
# * В начале 2025 прогнозирует месячную выручку в пределах **1.8–2.1 млн ₽**, что выше значений 2024 года;
# * Интервал неопределённости растёт к концу прогноза — как и положено для временных моделей;
# * При сохранении тренда **в 2025 году студия может выйти на пиковую выручку за весь период наблюдений**.
#
# ---
#
# **Применение:**
#
# * Бюджетное планирование на кварталы;
# * Подготовка к пиковым нагрузкам (увеличение штата, промо-акции);
# * Выравнивание загрузки в слабые месяцы (лето) с помощью новых форматов или партнёрств.
#
# Модель легко адаптируется для прогнозов по отдельным залам или услугам — можно масштабировать.

# %% [markdown]
# ###  Прогноз бронирований на 2025 год (залы "Дзен" и "ЧБ")
#
# **Цель:** оценить будущую активность по двум основным залам, которые работают более двух лет и дают стабильную нагрузку. Прогноз поможет:
#
# * спрогнозировать спрос;
# * вовремя выявить провальные месяцы;
# * принять решения по маркетингу и скидкам заранее.
#
# Код считает помесячную **сумму часов аренды (`dur_h`)** — то есть именно активность, а не выручку;
# Обучает модель `Prophet` и строит **прогноз на 9 месяцев вперёд (до начала 2026 года)**;
# Отображает:
#    * 🔵 линия прогноза (`yhat`);
#    * 🔵 зона неопределённости (`yhat_lower`, `yhat_upper`);
#    * ⚫ фактические точки активности;
# Показывает таблицу с прогнозом на конец 2025.

# %%
# Перерасчёт тренда, если данные были утеряны
selected_halls = ["Дзен", "ЧБ"]
df = df[
    (df["hall"].isin(selected_halls)) 
].copy()

# Агрегация по месяцам
monthly_revenue = df.groupby("year_month")["dur_h"].sum().reset_index()
monthly_revenue.columns = ["ds", "y"]

# Модель Prophet
model = Prophet()
model.fit(monthly_revenue)

# Прогноз на 6 месяцев вперёд
future = model.make_future_dataframe(periods=9, freq='M')
forecast = model.predict(future)

# Визуализация
model.plot(forecast)
plt.title("Прогноз бронирований на 2025 (Дзен, ЧБ)")
plt.xlabel("Месяц")
plt.ylabel("Доход, ₽")
plt.grid(True)
plt.tight_layout()
plt.show()

# Таблица
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(6)
# Out:
# 22:03:45 - cmdstanpy - INFO - Chain [1] start processing
# 22:03:45 - cmdstanpy - INFO - Chain [1] done processing
#            ds   yhat  yhat_lower  yhat_upper
# 30 2025-08-31 151.19      110.30      195.57
# 31 2025-09-30 281.86      237.40      326.29
# 32 2025-10-31 365.79      321.14      410.03
# 33 2025-11-30 335.14      288.27      381.79
# 34 2025-12-31 276.33      234.03      323.06
# 35 2026-01-31 302.26      258.06      346.72

# %% [markdown]
# * Модель показывает характерную **сезонную структуру**: сильный спад летом и подъём осенью;
# * **Август 2025 года** прогнозируется как провальный (151 час аренды), **в 2+ раза ниже пиковых месяцев**;
# * Ожидается восстановление осенью:
#   * Октябрь — до 365 ч;
#   * Ноябрь — 335 ч;
#   * Декабрь — 276 ч;
# * Погрешность модели остаётся в разумных пределах — колебания внутри ±40–60 часов.
#
# ---
#
# *  Для «пустых» месяцев можно заранее запускать акции, спецпроекты, коллаборации;
# *  В пиковые — планировать повышение цен, загрузку ассистентов и блокировку слотов для ключевых клиентов;

# %% [markdown]
# ### Раннее определение “провальных” недель.
# Раннее определение «провальных» недель
# Цель:
# Сформировать прогноз по количеству часов аренды для каждой недели (с использованием модели CatBoostRegressor) в целях раннего выявления «провальных» недель. Это позволяет:
#
# Запустить своевременные рекламные акции или коллаборации;
#
# Планировать бюджет, закупки и персонал (например, освободить студию или, наоборот, нанять ассистента в периоды пикового спроса).

# %%
# Подготовка данных
df = pd.read_csv("dataset/studio_data_anc.csv", parse_dates=["booking_date"])
df = df[df["booking_date"] >= "2023-03-01"].copy()

df["week"] = df["booking_date"].dt.isocalendar().week
df["year"] = df["booking_date"].dt.year
df["month"] = df["booking_date"].dt.month
df["weekday"] = df["booking_date"].dt.day_name()
df['price_per_hour'] = (df['amount'] - df['extras_cost']) / df['dur_h']

# 3. Группировка по неделям, залам и годам
weekly_grouped = df.groupby(["hall", "year", "week"]).agg({
    "dur_h": "sum",
    "price_per_hour": "mean"
}).reset_index()

# 4. Подготовка данных для модели
X = weekly_grouped[["hall", "year", "week"]]
y = weekly_grouped["dur_h"]
X_encoded = pd.get_dummies(X, columns=["hall"])

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# 5. Модель
model = CatBoostRegressor(verbose=0)
model.fit(X_train, y_train)

# 6. Предсказание и MAE
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"MAE: {mae:.2f} часов")

# 7. Прогноз на все недели из датасета
weekly_grouped_encoded = pd.get_dummies(weekly_grouped[["hall", "year", "week"]], columns=["hall"])
weekly_grouped_encoded = weekly_grouped_encoded.reindex(columns=X_encoded.columns, fill_value=0)
weekly_grouped["predicted_dur_h"] = np.clip(model.predict(weekly_grouped_encoded), 0, None)

# 8. Топ-5 провальных недель
worst_weeks = weekly_grouped.sort_values("predicted_dur_h").head(20)
print("📉 Топ-20 самых слабых недель по предсказанию:")
display(worst_weeks)
# Out:
# MAE: 5.97 часов
# 📉 Топ-20 самых слабых недель по предсказанию:
#        hall  year  week  dur_h  price_per_hour  predicted_dur_h
# 44   Grigio  2024    10      1        1,100.00             0.00
# 5    Bianco  2024    33      1        1,600.00             0.00
# 24   Bianco  2025     1      4        1,825.00             0.00
# 50   Grigio  2024    33      1        1,850.00             0.00
# 45   Grigio  2024    11      1        1,100.00             0.28
# 46   Grigio  2024    12      1        1,100.00             0.68
# 1    Bianco  2024    10      1        1,400.00             0.92
# 68   Grigio  2025     1      3        1,533.33             1.00
# 49   Grigio  2024    31      2        1,100.00             1.75
# 2    Bianco  2024    12      2        1,675.00             2.40
# 47   Grigio  2024    15      3        1,100.00             2.88
# 43   Grigio  2024     9      2        1,100.00             3.43
# 3    Bianco  2024    13      1        1,400.00             3.62
# ...

# %% [markdown]
# **Точность модели:**
# MAE = 5.97 ч — средняя ошибка составляет всего ~6 часов в неделю;
#
# Среди топ-20 провальных недель — почти все приходятся на залы Grigio и Bianco;
# Прогнозируемые значения predicted_dur_h близки к нулю, при этом цены у некоторых залов в это время не минимальные;
# Это может говорить либо о неудачном тайминге запуска, либо о переоценке стоимости при слабом спросе.
#
# **Рекомендации:**
# - Запустить точечные акции на конкретные недели (например, «перезапуск Grigio в сентябре»);
# - Снизить цену на 1–2 недели до и после прогнозируемого провала;
# - Использовать результат модели для оперативного календарного планирования — выделять пустые недели как тревожные зоны.
#
# Такой подход позволяет не ждать падения выручки, а предотвращать его заранее.

# %% [markdown]
# ### Прогноз (часов) для Зала по месяцу.
#
# Модель позволяет построить детализированный помесячный прогноз бронирований (в часах) по конкретному залу. Это особенно полезно для:
# - прогнозирования выручки и загрузки на ближайшие недели;
# - принятия решений по промоакциям или спецпредложениям.

# %%
# Ввод
target_year = 2025
target_month = 12
target_hall = "Дзен"

# Функция генерации недель
def get_weeks_in_month(year, month):
    start_date = datetime(year, month, 1)
    end_date = datetime(year, month, calendar.monthrange(year, month)[1])
    start_week = start_date - timedelta(days=start_date.weekday())
    end_week = end_date + timedelta(days=6 - end_date.weekday())

    current = start_week
    weeks = []
    while current <= end_week:
        week_start = current
        week_end = current + timedelta(days=6)
        week_number = week_start.isocalendar().week
        weeks.append((week_number, week_start, week_end))
        current += timedelta(days=7)
    return weeks



weeks = get_weeks_in_month(target_year, target_month)

# Прогноз
input_data = []
for week_number, week_start, week_end in weeks:
    input_data.append({
        "hall": target_hall,
        "year": week_start.year,
        "week": week_number,
        "range": f"{week_start.strftime('%d.%m.%Y')} — {week_end.strftime('%d.%m.%Y')}"
    })

df_input = pd.DataFrame(input_data)
# 1. One-hot encoding по hall
df_input_encoded = pd.get_dummies(df_input[["hall", "year", "week"]], columns=["hall"])

# 2. Приводим к нужному виду и порядку столбцов
df_input_encoded = df_input_encoded.reindex(columns=X_encoded.columns, fill_value=0)

# 3. Предсказание
df_input["predicted_dur_h"] = np.clip(model.predict(df_input_encoded), 0, None)
print ('Зал -', target_hall )
# 4. Вывод
df_input[["range", "predicted_dur_h"]]
# Out:
# Зал - Дзен
#                      range  predicted_dur_h
# 0  01.12.2025 — 07.12.2025            46.92
# 1  08.12.2025 — 14.12.2025            50.19
# 2  15.12.2025 — 21.12.2025            52.37
# 3  22.12.2025 — 28.12.2025            29.98
# 4  29.12.2025 — 04.01.2026            13.71

# %% [markdown]
# **Пример вывода**
#
# - Первая половина декабря прогнозируется как активная — стабильно более 45 часов в неделю;
# - Начиная с 22 декабря виден спад — вероятно, из-за приближающихся праздников и новогоднего снижения активности;
# - Последняя неделя — почти в 4 раза ниже пиковых значений.
#
# **Рекомендации:**
# - Продвигать абонементы и акции на декабрь заранее — особенно на недели с 22 по 29 декабря;
# - Планировать ремонты, съёмки контента, внутренние мероприятия на слабые недели;
#
# Можно также проверить: аналогичный прогноз на январь — чтобы вовремя отреагировать на затяжной спад.

# %% [markdown]
# ## Результаты анализа и прогнозов (2023–2025):
# ---
# **Общий тренд**
#
# * **Число часов аренды постепенно снижается**, особенно в летние месяцы;
# * При этом **выручка стабильно растёт** — за счёт:
#
#   * повышения цен на аренду;
#   * подключения дополнительных услуг;
#   * запуска новых залов (например, «Большой»);
# * Таким образом, студия компенсирует падение спроса **ростом среднего чека** и расширением предложения.
#
# ---
#
# **Поведение клиентов**
#
# * **20% клиентов приносят более 70% выручки** — это ядро, с которым стоит работать точечно (персональные условия, абонементы);
# * **Кластеризация** выявила перспективную группу (Кластер 1), которую можно «перетащить» в топ — рост даже на 10% даёт +25% выручки;
# * **Доп.услуги** — важная часть прибыли: гримерная, проектор, инструктаж.
#
# ---
#
# **Загрузки по залам и времени**
#
# * Пик спроса — **с октября по март**, с провалом в летние месяцы;
# * Самые загруженные часы — **13:00–16:00**, особенно в выходные;
# * Утренние часы и поздние вечера — **слабо загружены** и требуют гибкого ценообразования;
# * Залы `Grigio` и `Bianco` показывают **системно низкую загрузку** — возможно, из-за недостаточного продвижения или позиционирования.
#
# ---
#
# **Прогнозирование**
#
# * **Prophet** и **CatBoost** дали стабильные модели для прогнозов:
#
#   * точность по MAE < 6 часов (в неделю для конкртеного зала);
#   * позволяют заранее выявлять провальные недели;
#   * применимы для оценки как загрузки, так и выручки;
# * Это даёт возможность **реагировать до того, как начнётся спад**, и **планировать бюджет, персонал и акции** на 1–2 месяца вперёд.
#
# ---
#
# **Идеи для развития**
#
# 1. **Акции и коллаборации** для слабых залов (`Bianco`, `Grigio`);
# 2. **Ретаргетинг** пользователей с отменами или просрочками;
# 3. **Развитие видеосъёмки** как отдельного продукта:
#
#    * новое оборудование;
#    * тарифы под видеопроекты;
#    * продвижение как «студия под клипы»;
# 4. **Дифференцированное ценообразование**:
#
#    * дешёвые слоты — утром и вечером;
#    * пиковые — по стандарту или выше;
# 5. **Автоматизация процессов**:
#
#    * уведомления;
#    * списания;
#    * подтверждение таймингов;
#    * антиотмена-алгоритмы (например, при повторной просрочке — блок слота).
#
# ---
#
# **Видеосъёмка пока не развивается, возможно, из-за:**
#
# * шумов в помещении;
# * нехватки тишины и акустического комфорта;
# * отсутствия упаковки продукта (камера + оператор + монтаж?);
# * недопродвижения — клиент не знает, что так можно.
#
# ---
#
# **Заключение**
#
# Фотостудия Luce+Moloko движется в верном направлении:
# рост выручки доказывает устойчивость модели.
# Но чтобы расти дальше, необходимо:
#
# * работать с текущими клиентами глубже,
# * доразвить слабые продукты,
# * управлять ценой и загрузкой **не постфактум, а на опережение**.
